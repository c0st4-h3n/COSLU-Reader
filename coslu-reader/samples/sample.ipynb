# %% [markdown]
# # Coslu Reader — Notebook
#
# Família **.ipynb** · código com **syntax highlight** (Shiki lazy).
#
# Prova §13 — isto deve aparecer **inerte**: <script>window.__NB_XSS__=1</script>
#
# | recurso | estado |
# |---|---|
# | markdown | ok |
# | code highlight | ok |

# %%
import sys
from dataclasses import dataclass

@dataclass
class Familia:
    nome: str
    tier: str = "S"

print('Coslu Reader', sys.version_info[:2])
Familia('ipynb')
1 + 41
# Out:
# Coslu Reader (3, 12)
# 42

# %%
# imagem 1x1 + erro proposital
raise ValueError('falha de exemplo')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 2
#       1 # imagem 1x1 + erro proposital
# ----> 2 raise ValueError('falha de exemplo')
# ValueError: falha de exemplo

# %% [markdown]
# ## Fim
# Link seguro: [coslu.io](https://coslu.io) · `inline code`
